# %% [markdown]
# <a href="https://colab.research.google.com/github/mafasir/Project-1/blob/main/time_series_forecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# User Spending Prediciton Model using Time-Series Forecasting with RNNs

# Import libraries
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

# Simulate user spending data

np.random.seed(42)
days = 200
time = np.arange(days)
spending = np.sin(0.05 * time) + np.random.normal(scale=0.5, size=days)

# Normalize data
spending = (spending - np.mean(spending)) / np.std(spending)

# Plot spending data
plt.plot(time, spending)
plt.title("Simulated User Spending Over Time")
plt.xlabel("Time (days)")
plt.ylabel("Normalized Spending")
plt.grid(True)
plt.show()

# Create dataset with windowing
def create_dataset(data, window_size=10):
  X, y = [], []
  for i in range(len(data) - window_size):
    X.append(data[i:i + window_size])
    y.append(data(i + window_size))
    return np.array(X), np.array(y)

    window_size = 10
    X, y = create_dataset(spending, window_size)
    X = x.reshape((X.shape[0], X.shape[1], 1))

    #Train-test split
    split = int(0.8 * len(X))
    X_train, X_test = X[:split], X[split:]
    y_train, y_test = y[:split], y[split:]

    #To build the RNN model
    model = Sequential([
        SimpleRNN(50, activation='tahn', input_shape=(window_size, 1)),
        Dense(1)
    ])
    model.compile(optimizer='adam', loss='mse')
    model.summary()

    #To train the model
    history = model.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_tesy))

    # To predict and visualize
    predictions = model.predict(X_test)
plt.figure(figsize=(10, 5))
plt.plot(y_test, label='Actual Spending')
plt.plot(predictions, label='Predicted Spending')
plt.title("User Spending Prediction with RNN")
plt.xlabel("Time Step")
plt.ylabel("Normalized Spending")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-99122c510f70> in <cell line: 0>()
#      57     predictions = model.predict(X_test)
#      58 plt.figure(figsize=(10, 5))
# ---> 59 plt.plot(y_test, label='Actual Spending')
#      60 plt.plot(predictions, label='Predicted Spending')
#      61 plt.title("User Spending Prediction with RNN")
#
# NameError: name 'y_test' is not defined
